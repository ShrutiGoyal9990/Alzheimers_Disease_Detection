# %% [markdown]
# # **Alzheimer's Disease Detection**

# %% [markdown]
# **Loading the dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Import Statements**

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf
from tensorflow import keras
from keras import layers
import matplotlib.image as img
# %matplotlib inline

# %% [markdown]
# split-folders is a python package to split a dataset into training, validation, and test sets

# %%
# !pip install split-folders
import splitfolders
splitfolders.ratio('/content/drive/MyDrive/Dataset', output="output", seed=1345, ratio=(.8, 0.1,0.1))
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1
# Copying files: 6400 files [01:51, 57.60 files/s]

# %% [markdown]
# tf.keras.preprocessing.image_dataset_from_directory function to create TensorFlow tf.data.Dataset objects from the image datasets that were previously split and saved in the "output" directory.

# %%
IMG_HEIGHT = 128
IMG_WIDTH = 128
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
"./output/train",
seed=123,
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=64
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
"./output/test",
seed=123,
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=64
                                                               )

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
"./output/val",
seed=123,
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=64
)
# Out:
# Found 5119 files belonging to 4 classes.
# Found 642 files belonging to 4 classes.
# Found 639 files belonging to 4 classes.

# %%
class_names = train_ds.class_names
print(class_names)
train_ds
# Out:
# ['Mild_Demented', 'Moderate_Demented', 'Non_Demented', 'Very_Mild_Demented']
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# This code snippet is using Matplotlib to visualize a grid of images from the training dataset. It generates a 3x3 grid displaying the first 9 images from the training dataset, along with their corresponding class labels.

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# This bar plot shows the distribution or counts of different classes within the dataset.

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
size = [896,64,3200,2240]
ax.bar(class_names,size)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## **CNN (Convolutional Neural Network)**

# %% [markdown]
# **Loading the model**

# %%
model = keras.models.Sequential()
model.add(keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(IMG_HEIGHT,IMG_WIDTH, 3)))
model.add(keras.layers.Conv2D(filters=16,kernel_size=(3,3),padding='same',activation='relu',kernel_initializer="he_normal"))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))


model.add(keras.layers.Conv2D(filters=32,kernel_size=(3,3),padding='same',activation='relu',kernel_initializer="he_normal"))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))

model.add(keras.layers.Dropout(0.20))

model.add(keras.layers.Conv2D(filters=64,kernel_size=(3,3),padding='same',activation='relu',kernel_initializer="he_normal"))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))

model.add(keras.layers.Dropout(0.25))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(128,activation="relu",kernel_initializer="he_normal"))
model.add(keras.layers.Dense(64,"relu"))
model.add(keras.layers.Dense(4,"softmax"))

model.compile(loss="sparse_categorical_crossentropy",
              optimizer = "Adam",metrics=["accuracy"])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 128, 128, 3)       0
#
#  conv2d (Conv2D)             (None, 128, 128, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 32)        0
#  g2D)
#
#  dropout (Dropout)           (None, 32, 32, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 64)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 16, 16, 64)        0
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 128)               2097280
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 2129380 (8.12 MB)
# Trainable params: 2129380 (8.12 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Training the model**

# %%
hist = model.fit(train_ds,validation_data=val_ds,epochs=50, batch_size=32, verbose=1)
# Out:
# Epoch 1/50
# 80/80 [==============================] - 13s 59ms/step - loss: 1.2742 - accuracy: 0.4770 - val_loss: 1.0144 - val_accuracy: 0.5211
# Epoch 2/50
# 80/80 [==============================] - 3s 37ms/step - loss: 0.9600 - accuracy: 0.5341 - val_loss: 0.9446 - val_accuracy: 0.6275
# Epoch 3/50
# 80/80 [==============================] - 2s 26ms/step - loss: 0.8877 - accuracy: 0.5862 - val_loss: 0.8305 - val_accuracy: 0.6291
# Epoch 4/50
# 80/80 [==============================] - 2s 26ms/step - loss: 0.8362 - accuracy: 0.6122 - val_loss: 0.7311 - val_accuracy: 0.6839
# Epoch 5/50
# 80/80 [==============================] - 2s 25ms/step - loss: 0.7337 - accuracy: 0.6745 - val_loss: 0.6652 - val_accuracy: 0.7293
# Epoch 6/50
# 80/80 [==============================] - 2s 27ms/step - loss: 0.6543 - accuracy: 0.7162 - val_loss: 0.5578 - val_accuracy: 0.7809
# Epoch 7/50
# 80/80 [==============================] - 3s 35ms/step - loss: 0.5386 - accuracy: 0.7722 - val_loss: 0.4229 - val_accuracy: 0.8435
# Epoch 8/50
# 80/80 [==============================] - 3s 37ms/step - loss: 0.4266 - accuracy: 0.8283 - val_loss: 0.3812 - val_accuracy: 0.8388
# Epoch 9/50
# 80/80 [==============================] - 2s 26ms/step - loss: 0.3820 - accuracy: 0.8449 - val_loss: 0.3205 - val_accuracy: 0.8826
# Epoch 10/50
# 80/80 [==============================] - 2s 26ms/step - loss: 0.2885 - accuracy: 0.8885 - val_loss: 0.2091 - val_accuracy: 0.9280
# Epoch 11/50
# 80/80 [==============================] - 2s 27ms/step - loss: 0.2515 - accuracy: 0.9039 - val_loss: 0.2012 - val_accuracy: 0.9311
# Epoch 12/50
# 80/80 [==============================] - 3s 37ms/step - loss: 0.2171 - accuracy: 0.9166 - val_loss: 0.1301 - val_accuracy: 0.9624
# Epoch 13/50
# 80/80 [==============================] - 2s 28ms/step - loss: 0.1761 - accuracy: 0.9342 - val_loss: 0.1032 - val_accuracy: 0.9765
# Epoch 14/50
# 80/80 [==============================] - 2s 26ms/step - loss: 0.1461 - accuracy: 0.9469 - val_loss: 0.0985 - val_accuracy: 0.9812
# Epoch 15/50
# 80/80 [==============================] - 2s 27ms/step - loss: 0.1278 - accuracy: 0.9545 - val_loss: 0.0928 - val_accuracy: 0.9750
# Epoch 16/50
# 80/80 [==============================] - 2s 30ms/step - loss: 0.1037 - accuracy: 0.9619 - val_loss: 0.0671 - val_accuracy: 0.9781
# Epoch 17/50
# 80/80 [==============================] - 4s 46ms/step - loss: 0.1048 - accuracy: 0.9635 - val_loss: 0.0684 - val_accuracy: 0.9828
# Epoch 18/50
# 80/80 [==============================] - 2s 27ms/step - loss: 0.0846 - accuracy: 0.9685 - val_loss: 0.0690 - val_accuracy: 0.9797
# Epoch 19/50
# 80/80 [==============================] - 2s 29ms/step - loss: 0.0972 - accuracy: 0.9670 - val_loss: 0.0718 - val_accuracy: 0.9797
# Epoch 20/50
# 80/80 [==============================] - 2s 27ms/step - loss: 0.0887 - accuracy: 0.9691 - val_loss: 0.0418 - val_accuracy: 0.9906
# Epoch 21/50
# 80/80 [==============================] - 2s 29ms/step - loss: 0.0519 - accuracy: 0.9836 - val_loss: 0.0279 - val_accuracy: 0.9937
# Epoch 22/50
# 80/80 [==============================] - 3s 37ms/step - loss: 0.0554 - accuracy: 0.9799 - val_loss: 0.0356 - val_accuracy: 0.9890
# Epoch 23/50
# 80/80 [==============================] - 2s 27ms/step - loss: 0.0584 - accuracy: 0.9783 - val_loss: 0.0299 - val_accuracy: 0.9937
# Epoch 24/50
# 80/80 [==============================] - 2s 29ms/step - loss: 0.0458 - accuracy: 0.9826 - val_loss: 0.0361 - val_accuracy: 0.9890
# Epoch 25/50
# 80/80 [==============================] - 2s 26ms/step - loss: 0.0448 - accuracy: 0.9832 - val_loss: 0.0749 - val_accuracy: 0.9734
# Epoch 26/50
# 80/80 [==============================] - 3s 34ms/step - loss: 0.0490 - accuracy: 0.9859 - val_loss: 0.0393 - val_accuracy: 0.9875
# Epoch 27/50
# 80/80 [==============================] - 4s 48ms/step - loss: 0.0579 - accuracy: 0.9797 - val_loss: 0.0220 - val_accuracy: 0.9953
# Epoch 28/50
# 80/80 [==============================] - 2s 27ms/step - loss: 0.0310 - accuracy: 0.9895 - val_loss: 0.0172 - val_accuracy: 0.9953
# Epoch 29/50
# 80/80 [==============================] - 2s 28ms/step - loss: 0.0336 - accuracy: 0.9877 - val_loss: 0.0232 - val_accuracy: 0.9906
# Epoch 30/50
# 80/80 [==============================] - 2s 27ms/step - loss: 0.0310 - accuracy: 0.9879 - val_loss: 0.0382 - val_accuracy: 0.9890
# Epoch 31/50
# 80/80 [==============================] - 2s 28ms/step - loss: 0.0420 - accuracy: 0.9853 - val_loss: 0.0218 - val_accuracy: 0.9937
# Epoch 32/50
# 80/80 [==============================] - 4s 42ms/step - loss: 0.0492 - accuracy: 0.9824 - val_loss: 0.0310 - val_accuracy: 0.9937
# Epoch 33/50
# 80/80 [==============================] - 2s 28ms/step - loss: 0.0354 - accuracy: 0.9875 - val_loss: 0.0252 - val_accuracy: 0.9937
# Epoch 34/50
# 80/80 [==============================] - 2s 28ms/step - loss: 0.0221 - accuracy: 0.9934 - val_loss: 0.0126 - val_accuracy: 0.9969
# Epoch 35/50
# 80/80 [==============================] - 2s 29ms/step - loss: 0.0250 - accuracy: 0.9900 - val_loss: 0.0192 - val_accuracy: 0.9937
# Epoch 36/50
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0299 - accuracy: 0.9891 - val_loss: 0.0242 - val_accuracy: 0.9937
# Epoch 37/50
# 80/80 [==============================] - 3s 37ms/step - loss: 0.0273 - accuracy: 0.9898 - val_loss: 0.0138 - val_accuracy: 0.9937
# Epoch 38/50
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0224 - accuracy: 0.9924 - val_loss: 0.0219 - val_accuracy: 0.9937
# Epoch 39/50
# 80/80 [==============================] - 2s 26ms/step - loss: 0.0343 - accuracy: 0.9895 - val_loss: 0.0663 - val_accuracy: 0.9781
# Epoch 40/50
# 80/80 [==============================] - 2s 27ms/step - loss: 0.0283 - accuracy: 0.9906 - val_loss: 0.0304 - val_accuracy: 0.9875
# Epoch 41/50
# 80/80 [==============================] - 2s 28ms/step - loss: 0.0170 - accuracy: 0.9943 - val_loss: 0.0155 - val_accuracy: 0.9937
# Epoch 42/50
# 80/80 [==============================] - 3s 31ms/step - loss: 0.0207 - accuracy: 0.9928 - val_loss: 0.0212 - val_accuracy: 0.9937
# Epoch 43/50
# 80/80 [==============================] - 2s 27ms/step - loss: 0.0279 - accuracy: 0.9906 - val_loss: 0.0093 - val_accuracy: 0.9984
# Epoch 44/50
# 80/80 [==============================] - 2s 26ms/step - loss: 0.0239 - accuracy: 0.9914 - val_loss: 0.0200 - val_accuracy: 0.9953
# Epoch 45/50
# 80/80 [==============================] - 2s 26ms/step - loss: 0.0316 - accuracy: 0.9895 - val_loss: 0.0502 - val_accuracy: 0.9844
# Epoch 46/50
# 80/80 [==============================] - 3s 32ms/step - loss: 0.0236 - accuracy: 0.9936 - val_loss: 0.0354 - val_accuracy: 0.9875
# Epoch 47/50
# 80/80 [==============================] - 2s 29ms/step - loss: 0.0248 - accuracy: 0.9906 - val_loss: 0.0402 - val_accuracy: 0.9859
# Epoch 48/50
# 80/80 [==============================] - 2s 26ms/step - loss: 0.0259 - accuracy: 0.9902 - val_loss: 0.0093 - val_accuracy: 0.9969
# Epoch 49/50
# 80/80 [==============================] - 2s 29ms/step - loss: 0.0258 - accuracy: 0.9914 - val_loss: 0.0068 - val_accuracy: 0.9984
# Epoch 50/50
# 80/80 [==============================] - 2s 28ms/step - loss: 0.0126 - accuracy: 0.9953 - val_loss: 0.0224 - val_accuracy: 0.9937

# %% [markdown]
# **Testing Analysis**

# %%
get_ac = hist.history['accuracy']
get_los = hist.history['loss']
val_acc = hist.history['val_accuracy']
val_loss = hist.history['val_loss']

# %%
epochs = range(len(get_ac))
plt.plot(epochs, get_ac, 'g', label='Accuracy of Training data')
plt.plot(epochs, get_los, 'r', label='Loss of Training data')
plt.title('Training data accuracy and loss')
plt.legend(loc=0)
plt.figure()

plt.plot(epochs, get_ac, 'g', label='Accuracy of Training Data')
plt.plot(epochs, val_acc, 'r', label='Accuracy of Validation Data')
plt.title('Training and Validation Accuracy')
plt.legend(loc=0)
plt.figure()

plt.plot(epochs, get_los, 'g', label='Loss of Training Data')
plt.plot(epochs, val_loss, 'r', label='Loss of Validation Data')
plt.title('Training and Validation Loss')
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
loss, accuracy = model.evaluate(test_ds)
# Out:
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0227 - accuracy: 0.9953

# %%
from tensorflow.keras.utils import plot_model
plot_model(model,to_file='model_cnn_architecture.jpg',show_shapes=True,show_layer_names=True)

# %%
plt.figure(figsize=(20, 20))
for images, labels in test_ds.take(1):
    for i in range(16):
        ax = plt.subplot(4, 4, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        predictions = model.predict(tf.expand_dims(images[i], 0))
        score = tf.nn.softmax(predictions[0])
        if(class_names[labels[i]]==class_names[np.argmax(score)]):
            plt.title("Actual: "+class_names[labels[i]])
            plt.ylabel("Predicted: "+class_names[np.argmax(score)],fontdict={'color':'green'})

        else:
            plt.title("Actual: "+class_names[labels[i]])
            plt.ylabel("Predicted: "+class_names[np.argmax(score)],fontdict={'color':'red'})
        plt.gca().axes.yaxis.set_ticklabels([])
        plt.gca().axes.xaxis.set_ticklabels([])
# Out:
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
