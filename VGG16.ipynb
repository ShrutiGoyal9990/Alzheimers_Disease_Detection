# %% [markdown]
# # **Alzheimer's Disease Detection**

# %% [markdown]
# **Loading the dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Import Statements**

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf
from tensorflow import keras
from keras import layers
import matplotlib.image as img
# %matplotlib inline

# %% [markdown]
# split-folders is a python package to split a dataset into training, validation, and test sets

# %%
# !pip install split-folders
import splitfolders
splitfolders.ratio('/content/drive/MyDrive/Dataset', output="output", seed=1345, ratio=(.8, 0.1,0.1))
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1
# Copying files: 6400 files [01:51, 57.60 files/s]

# %% [markdown]
# tf.keras.preprocessing.image_dataset_from_directory function to create TensorFlow tf.data.Dataset objects from the image datasets that were previously split and saved in the "output" directory.

# %%
IMG_HEIGHT = 128
IMG_WIDTH = 128
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
"./output/train",
seed=123,
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=64
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
"./output/test",
seed=123,
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=64
                                                               )

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
"./output/val",
seed=123,
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=64
)
# Out:
# Found 5119 files belonging to 4 classes.
# Found 642 files belonging to 4 classes.
# Found 639 files belonging to 4 classes.

# %%
class_names = train_ds.class_names
print(class_names)
train_ds
# Out:
# ['Mild_Demented', 'Moderate_Demented', 'Non_Demented', 'Very_Mild_Demented']
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# This code snippet is using Matplotlib to visualize a grid of images from the training dataset. It generates a 3x3 grid displaying the first 9 images from the training dataset, along with their corresponding class labels.

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# This bar plot shows the distribution or counts of different classes within the dataset.

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
size = [896,64,3200,2240]
ax.bar(class_names,size)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## **VGG16 (Visual Geometry Group - 16)**

# %% [markdown]
# **Loading the model**

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam

# Load the pre-trained Xception model without the top (classification) layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(IMG_HEIGHT,IMG_WIDTH, 3))

# Freeze the pre-trained layers
base_model.trainable = True

# Create a new model on top
modelV = Sequential()
modelV.add(base_model)
modelV.add(GlobalAveragePooling2D())
modelV.add(keras.layers.Dense(128,activation="relu",kernel_initializer="he_normal"))
modelV.add(keras.layers.Dense(4,"softmax"))  # 4 classes: mild_demented, moderate_demented, non_demented, very_mild_demented

# Compile the model
modelV.compile(loss="sparse_categorical_crossentropy",
              optimizer = Adam(learning_rate = 0.0008),metrics=["accuracy"])

# Summary of the model architecture
modelV.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  global_average_pooling2d_1  (None, 512)               0
#  4 (GlobalAveragePooling2D)
#
#  dense_31 (Dense)            (None, 128)               65664
#
#  dense_32 (Dense)            (None, 4)                 516
#
# =================================================================
# Total params: 14780868 (56.38 MB)
# Trainable params: 14780868 (56.38 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Training the model**

# %%
hist = modelV.fit(train_ds, validation_data=val_ds,epochs=50, batch_size=32, verbose=1)
# Out:
# Epoch 1/50
# 80/80 [==============================] - 24s 253ms/step - loss: 4.7156 - accuracy: 0.4546 - val_loss: 1.0420 - val_accuracy: 0.5008
# Epoch 2/50
# 80/80 [==============================] - 20s 254ms/step - loss: 1.0437 - accuracy: 0.5003 - val_loss: 1.0289 - val_accuracy: 0.5008
# Epoch 3/50
# 80/80 [==============================] - 20s 251ms/step - loss: 1.0414 - accuracy: 0.4991 - val_loss: 1.0399 - val_accuracy: 0.5023
# Epoch 4/50
# 80/80 [==============================] - 20s 253ms/step - loss: 1.0443 - accuracy: 0.4946 - val_loss: 1.0356 - val_accuracy: 0.5102
# Epoch 5/50
# 80/80 [==============================] - 21s 258ms/step - loss: 1.0499 - accuracy: 0.4919 - val_loss: 1.0391 - val_accuracy: 0.5008
# Epoch 6/50
# 80/80 [==============================] - 21s 264ms/step - loss: 1.0276 - accuracy: 0.5028 - val_loss: 1.0041 - val_accuracy: 0.5587
# Epoch 7/50
# 80/80 [==============================] - 21s 266ms/step - loss: 1.0143 - accuracy: 0.5173 - val_loss: 0.9653 - val_accuracy: 0.5743
# Epoch 8/50
# 80/80 [==============================] - 21s 259ms/step - loss: 0.9887 - accuracy: 0.5372 - val_loss: 0.9271 - val_accuracy: 0.5994
# Epoch 9/50
# 80/80 [==============================] - 21s 260ms/step - loss: 0.9727 - accuracy: 0.5599 - val_loss: 0.9683 - val_accuracy: 0.5180
# Epoch 10/50
# 80/80 [==============================] - 21s 259ms/step - loss: 0.9421 - accuracy: 0.5677 - val_loss: 0.8783 - val_accuracy: 0.6166
# Epoch 11/50
# 80/80 [==============================] - 21s 260ms/step - loss: 0.9500 - accuracy: 0.5614 - val_loss: 0.8704 - val_accuracy: 0.6354
50
# 80/80 [==============================] - 21s 265ms/step - loss: 0.1290 - accuracy: 0.9508 - val_loss: 0.3645 - val_accuracy: 0.8998
# Epoch 36/50
# 80/80 [==============================] - 21s 260ms/step - loss: 0.1064 - accuracy: 0.9641 - val_loss: 0.3454 - val_accuracy: 0.8795
# Epoch 37/50
# 80/80 [==============================] - 22s 267ms/step - loss: 0.1159 - accuracy: 0.9545 - val_loss: 0.3200 - val_accuracy: 0.8920
# Epoch 38/50
# 80/80 [==============================] - 21s 261ms/step - loss: 0.0610 - accuracy: 0.9799 - val_loss: 0.5696 - val_accuracy: 0.8560
# Epoch 39/50
# 80/80 [==============================] - 21s 261ms/step - loss: 0.0601 - accuracy: 0.9799 - val_loss: 0.3170 - val_accuracy: 0.9045
# Epoch 40/50
# 80/80 [==============================] - 21s 265ms/step - loss: 0.0372 - accuracy: 0.9871 - val_loss: 0.3942 - val_accuracy: 0.9092
# Epoch 41/50
# 80/80 [==============================] - 21s 263ms/step - loss: 0.0772 - accuracy: 0.9723 - val_loss: 0.2980 - val_accuracy: 0.9045
# Epoch 42/50
# 80/80 [==============================] - 21s 264ms/step - loss: 0.0438 - accuracy: 0.9863 - val_loss: 0.2400 - val_accuracy: 0.9311
# Epoch 43/50
# 80/80 [==============================] - 22s 268ms/step - loss: 0.0302 - accuracy: 0.9889 - val_loss: 0.2151 - val_accuracy: 0.9358
# Epoch 44/50
# 80/80 [==============================] - 21s 263ms/step - loss: 0.0861 - accuracy: 0.9719 - val_loss: 0.3319 - val_accuracy: 0.8811
# Epoch 45/50
# 80/80 [==============================] - 21s 263ms/step - loss: 0.0545 - accuracy: 0.9803 - val_loss: 0.3515 - val_accuracy: 0.9045
# Epoch 46/50
# 80/80 [==============================] - 22s 267ms/step - loss: 0.0404 - accuracy: 0.9869 - val_loss: 0.2472 - val_accuracy: 0.9343
# Epoch 47/50
# 80/80 [==============================] - 21s 265ms/step - loss: 0.0828 - accuracy: 0.9711 - val_loss: 0.2181 - val_accuracy: 0.9343
# Epoch 48/50
# 80/80 [==============================] - 21s 263ms/step - loss: 0.0410 - accuracy: 0.9869 - val_loss: 0.3574 - val_accuracy: 0.8873
# Epoch 49/50
# 80/80 [==============================] - 21s 262ms/step - loss: 0.0372 - accuracy: 0.9869 - val_loss: 0.3226 - val_accuracy: 0.9233
# Epoch 50/50
# 80/80 [==============================] - 21s 258ms/step - loss: 0.0474 - accuracy: 0.9844 - val_loss: 0.3231 - val_accuracy: 0.9171

# %% [markdown]
# **Testing Analysis**

# %%
loss, accuracyV = modelV.evaluate(test_ds)
print(f"Test Accuracy: {accuracyV:.4f}")
# Out:
# 11/11 [==============================] - 2s 154ms/step - loss: 0.3879 - accuracy: 0.9034
# Test Accuracy: 0.9034

# %%
from tensorflow.keras.utils import plot_model
plot_model(modelV,to_file='model_vgg_architecture.jpg',show_shapes=True,show_layer_names=True)

# %%
get_ac = hist.history['accuracy']
get_los = hist.history['loss']
val_acc = hist.history['val_accuracy']
val_loss = hist.history['val_loss']

# %%
epochs = range(len(get_ac))
plt.plot(epochs, get_ac, 'g', label='Accuracy of Training data')
plt.plot(epochs, get_los, 'r', label='Loss of Training data')
plt.title('Training data accuracy and loss')
plt.legend(loc=0)
plt.figure()

plt.plot(epochs, get_ac, 'g', label='Accuracy of Training Data')
plt.plot(epochs, val_acc, 'r', label='Accuracy of Validation Data')
plt.title('Training and Validation Accuracy')
plt.legend(loc=0)
plt.figure()

plt.plot(epochs, get_los, 'g', label='Loss of Training Data')
plt.plot(epochs, val_loss, 'r', label='Loss of Validation Data')
plt.title('Training and Validation Loss')
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
plt.figure(figsize=(20, 20))
for images, labels in test_ds.take(1):
    for i in range(16):
        ax = plt.subplot(4, 4, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        predictions = modelV.predict(tf.expand_dims(images[i], 0))
        score = tf.nn.softmax(predictions[0])
        if(class_names[labels[i]]==class_names[np.argmax(score)]):
            plt.title("Actual: "+class_names[labels[i]])
            plt.ylabel("Predicted: "+class_names[np.argmax(score)],fontdict={'color':'green'})

        else:
            plt.title("Actual: "+class_names[labels[i]])
            plt.ylabel("Predicted: "+class_names[np.argmax(score)],fontdict={'color':'red'})
        plt.gca().axes.yaxis.set_ticklabels([])
        plt.gca().axes.xaxis.set_ticklabels([])
# Out:
# 1/1 [==============================] - 1s 947ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
